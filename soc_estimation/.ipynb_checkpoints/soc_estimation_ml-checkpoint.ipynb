# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf
tf.test.is_gpu_available()
# Out:
# False

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16312049190731367669
# xla_global_id: -1
# ]

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from scipy.io import loadmat
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# # Definitions and Data Importing

# %% [markdown]
# ## Paths Declaration
# Qui, di seguito, vengono riportati i path relativi al dataset di training, validation e testing. In particolare, il dataset di validation coincide con il primo dataset di testing contenuto nella cartella './LGHG2@n10C_to_25degC/Test'. Infatti, all'interno della directory './LGHG2@n10C_to_25degC/Test' sono presenti 5 possibili insiemi di dati così da poter essere sfruttati durante il testing.

# %%
folderTrainPath = './LGHG2@n10C_to_25degC/Train'
print(os.listdir(folderTrainPath))

folderValidationPath = './LGHG2@n10C_to_25degC/Test'
print(os.listdir(folderValidationPath))

folderTestPath = './LGHG2@n10C_to_25degC/Test'
print(os.listdir(folderTestPath))
# Out:
# ['.ipynb_checkpoints', 'TRAIN_LGHG2@n10degC_to_25degC_Norm_5Inputs.mat']
# ['01_TEST_LGHG2@n10degC_Norm_(05_Inputs).mat', '02_TEST_LGHG2@0degC_Norm_(05_Inputs).mat', '03_TEST_LGHG2@10degC_Norm_(05_Inputs).mat', '04_TEST_LGHG2@25degC_Norm_(05_Inputs).mat']
# ['01_TEST_LGHG2@n10degC_Norm_(05_Inputs).mat', '02_TEST_LGHG2@0degC_Norm_(05_Inputs).mat', '03_TEST_LGHG2@10degC_Norm_(05_Inputs).mat', '04_TEST_LGHG2@25degC_Norm_(05_Inputs).mat']

# %% [markdown]
# ## Training Dataset Import

# %%
dataTrainFileName = os.listdir(folderTrainPath)[1]
dataTrainPath = os.path.join(folderTrainPath, dataTrainFileName)
matdataTrain = loadmat(dataTrainPath)
matdataTrainX = matdataTrain['X']
matdataTrainY = matdataTrain['Y']
print(f"Shape of matdataTrainX: {matdataTrainX.shape}")
print(f"Shape of matdataTrainY: {matdataTrainY.shape}")
# Out:
# Shape of matdataTrainX: (5, 669956)
# Shape of matdataTrainY: (1, 669956)

# %% [markdown]
# ## Validation Dataset Import

# %%
dataValidationFileName = os.listdir(folderValidationPath)[3]
dataValidationPath = os.path.join(folderValidationPath, dataValidationFileName)
matdataValidation = loadmat(dataValidationPath)
matdataValidationX = matdataValidation['X']
matdataValidationY = matdataValidation['Y']
print(f"Shape of matdataValidationX: {matdataValidationX.shape}")
print(f"Shape of matdataValidationY: {matdataValidationY.shape}")
# Out:
# Shape of matdataValidationX: (5, 47517)
# Shape of matdataValidationY: (1, 47517)

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Distribution Plots

# %%
fig, axs = plt.subplots(1, 5, figsize=(20, 4))
for i in range(matdataTrainX.shape[0]):
    axs[i].hist(matdataTrainX[i,:], bins=30, alpha=0.75)
    feature = ''
    if i==0:
        feature = 'V'
    elif i==1:
        feature = 'I'
    elif i==2:
        feature = 'Temp'
    elif i==3:
        feature = 'V_avg'
    elif i==4:
        feature = 'I_avg'
    axs[i].legend([f'Feature: {feature}'])
plt.tight_layout()
plt.suptitle('Distribution of Independent Variables (X)', fontsize=16, y=1.06)
plt.show()

# %%
plt.hist(matdataTrainY[0,:], bins=30, alpha=0.75)
plt.title('Distribution of the Dependent Variable (Y)')
plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
data_combined = np.hstack((matdataTrainX.T, matdataTrainY.T))
correlation_matrix = np.corrcoef(data_combined, rowvar=False)

# Correlation matrix heat map
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='none')
plt.colorbar()
plt.title('Correlation Matrix between X and Y')
plt.show()

# %% [markdown]
# ## Time Series Analysis

# %%
# Time series of X variables
for i in range(5):
    plt.subplot(5, 1, i + 1)
    plt.plot(matdataTrainX[i, :])
    feature = ''
    if i==0:
        feature = 'V'
    elif i==1:
        feature = 'I'
    elif i==2:
        feature = 'Temp'
    elif i==3:
        feature = 'V_avg'
    elif i==4:
        feature = 'I_avg'
    plt.title(f'Time Series of Feature: {feature}')
plt.tight_layout()
plt.show()

# %%
# Time Series of Y
plt.plot(matdataTrainY[0,:])
plt.title('Time Series of Y')
plt.show()

# %%
print(matdataTrain.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'Y'])

# %%
import scipy.io
import pandas as pd

mat = scipy.io.loadmat(dataTrainPath)
mat = {k:v for k, v in mat.items() if k[0] != '_'}
data = pd.DataFrame({k: pd.Series(v[0]) for k, v in mat.items()})
data.to_csv("example.csv")
